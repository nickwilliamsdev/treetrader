# %%
import ta
import pandas as pd

vix_df = pd.read_csv('./hist_data/kaggle/vix_daily.csv', parse_dates=['date'])
vix_df = vix_df.set_index('date')
vix_df.head()
vix_df['SMA_10'] = (vix_df['close'] - ta.trend.sma_indicator(vix_df['close'], window=10)) / vix_df['close']
vix_df['SMA_30'] = (vix_df['close'] - ta.trend.sma_indicator(vix_df['close'], window=30)) / vix_df['close']
vix_df['EMA_10'] = (vix_df['close'] - ta.trend.ema_indicator(vix_df['close'], window=10)) / vix_df['close']
vix_df['EMA_30'] = (vix_df['close'] - ta.trend.ema_indicator(vix_df['close'], window=30)) / vix_df['close']
vix_df['RSI'] = ta.momentum.rsi(vix_df['close'], window=14) / 100
vix_df['MACD'] = ta.trend.macd(vix_df['close'])
vix_df['MACD_Signal'] = ta.trend.macd_signal(vix_df['close'])

vix_df = vix_df.dropna()
vix_df.head()
# Out:
#                  open       high        low      close    SMA_10    SMA_30  \
# date
# 1990-02-16  20.780001  20.780001  20.780001  20.780001 -0.114822 -0.154524
# 1990-02-20  22.780001  22.780001  22.780001  22.780001 -0.009219 -0.056848
# 1990-02-21  23.889999  23.889999  23.889999  23.889999  0.041021 -0.010102
# 1990-02-22  22.540001  22.540001  22.540001  22.540001 -0.008651 -0.070748
# 1990-02-23  23.690001  23.690001  23.690001  23.690001  0.040650 -0.023892
#
#               EMA_10    EMA_30       RSI      MACD  MACD_Signal
# date
# 1990-02-16 -0.093277 -0.102696  0.406281 -0.133833     0.563419
# 1990-02-20  0.002216 -0.005504  0.490742 -0.137011     0.423333
# 1990-02-21  0.039744  0.038556  0.530649 -0.049392     0.328788
# 1990-02-22 -0.014538 -0.017801  0.481254 -0.087874     0.245456
# 1990-02-23  0.028400  0.029568  0.522067 -0.025285     0.191308

# %%
import jax.numpy as jnp
train_test_split = 0.8
#vix_df['returns'] = (vix_df['close'] - vix_df['open']) / vix_df['open']
#vix_df['returns'] = vix_df['returns'].shift(-1)
vix_df['returns'] = vix_df['open'].pct_change().shift(-2)
vix_df = vix_df.dropna()

input_features = ['close', 'SMA_10', 'SMA_30', 'EMA_10', 'EMA_30', 'RSI', 'MACD', 'MACD_Signal']
INPUTS = jnp.array(vix_df[input_features].values)
RETURNS = jnp.expand_dims(jnp.array(vix_df['returns'].values), 1)

print(f"Shape of INPUTS: {INPUTS.shape}")
print(f"Shape of RETURNS: {RETURNS.shape}")

sample_count = INPUTS.shape[0]
print(f"Sample Count: {sample_count}")
train_size = int(sample_count * train_test_split)
print(f"Train Size: {train_size}")
TEST_INPUTS = INPUTS[train_size:, :]
TEST_RETURNS = RETURNS[train_size:, :]
INPUTS = INPUTS[:train_size, :]
RETURNS = RETURNS[:train_size, :]
# Out:
# Shape of INPUTS: (8650, 8)
# Shape of RETURNS: (8650, 1)
# Sample Count: 8650
# Train Size: 6920

# %%
import jax, jax.numpy as jnp
from tensorneat.problem.base import BaseProblem
import tensorneat.algorithm.neat as neat_algorithm
import matplotlib.pyplot as plt
import random
EPISODE_LEN = 34

class TradingProblem(BaseProblem):
  jitable = True
  episode_len = EPISODE_LEN
  pop_size = 1000
  
  def __init__(self):
      super().__init__()
      self.pop_counter = 0
      self.start_idx = random.randint(0, INPUTS.shape[0] - self.episode_len)
      self.end_idx = self.start_idx + self.episode_len

  @property
  def input_shape(self):
    return (INPUTS.shape[1],)

  @property
  def output_shape(self):
    return (1,)

  def evaluate(self, state, randkey, act_func, params):
    self.pop_counter += 1
    if self.pop_counter % self.pop_size == 0:
      self.start_idx = random.randint(0, INPUTS.shape[0] - self.episode_len)
      self.end_idx = self.start_idx + self.episode_len
    ins = INPUTS[self.start_idx:self.end_idx]
    returns = RETURNS[self.start_idx:self.end_idx]
    actions = jax.vmap(act_func, in_axes=(None, None, 0))(state, params, INPUTS)
    actions_buy_sell = jnp.where(actions > 0.0, 1, 0)
    reward = actions_buy_sell * RETURNS
    return jnp.mean(reward)

  def show(self, state, randkey, act_func, params, *args, **kwargs):
    # get actions as a host numpy array
    actions = jax.vmap(act_func, in_axes=(None, None, 0))(state, params, TEST_INPUTS)
    actions_buy_sell = jnp.where(actions > 0.0, 1, 0)

    # move data to host numpy
    from jax import device_get
    import numpy as np
    actions_np = np.asarray(device_get(actions_buy_sell)).ravel()
    returns_np = np.asarray(device_get(TEST_RETURNS)).ravel()

    perf = 100.0
    perf_hist = []
    for i in range(len(actions_np)):
      perf += perf * float(returns_np[i] * actions_np[i])
      perf_hist.append(float(perf))

    # plot using numpy list of floats
    import matplotlib.pyplot as plt
    plt.plot(perf_hist)
    print(perf_hist[0], perf_hist[-1])
    plt.show()

# Assuming INPUTS and RETURNS are defined from previous cells
trading_problem = TradingProblem()

# %%
import jax.numpy as jnp
import pickle
from tensorneat.pipeline import Pipeline
from tensorneat.algorithm.neat import NEAT
from tensorneat.genome import DefaultGenome, BiasNode, DefaultConn, DefaultMutation
from tensorneat.problem.func_fit import CustomFuncFit
from tensorneat.common import ACT, AGG
from tensorneat import algorithm

# Construct the pipeline and run
pipeline = Pipeline(
    algorithm=NEAT(
        pop_size=89,
        species_size=5,
        survival_threshold=0.1,
        compatibility_threshold=0.8,
        genome=DefaultGenome(
            max_nodes=100,
            max_conns=1500,
            num_inputs=8,
            num_outputs=1,
            init_hidden_layers=(10,),
            node_gene=BiasNode(
                bias_init_std=0.1,
                bias_mutate_power=0.05,
                bias_mutate_rate=0.01,
                bias_replace_rate=0.0,
                activation_options=ACT.tanh,
                aggregation_options=AGG.sum,
            ),
            conn_gene=DefaultConn(
                weight_init_mean=0.0,
                weight_init_std=0.1,
                weight_mutate_power=0.05,
                weight_replace_rate=0.0,
                weight_mutate_rate=0.001,
            ),
            output_transform=ACT.tanh,
        ),
    ),
    problem=TradingProblem(),
    generation_limit=30,
    fitness_target=.01,
    seed=42,
    is_save=True,
    save_dir="./model_archive/tensorneat_checkpoints"
)

# initialize state
state = pipeline.setup()
# run until terminate
state, best = pipeline.auto_run(state)
# show result
pipeline.show(state, best)
# Out:
# save to ./model_archive/tensorneat_checkpoints
# initializing
# initializing finished
# start compile
# compile finished, cost time: 3.536245s
# Generation: 1, Cost time: 1528.86ms
#  	fitness: valid cnt: 89, max: 0.0033, min: -0.0018, mean: 0.0011, std: 0.0012
#
# 	node counts: max: 20, min: 18, mean: 19.04
#  	conn counts: max: 91, min: 80, mean: 89.30
#  	species: 1, [89]
#
# Generation: 2, Cost time: 1469.07ms
#  	fitness: valid cnt: 89, max: 0.0033, min: -0.0014, mean: 0.0013, std: 0.0012
#
# 	node counts: max: 20, min: 18, mean: 18.97
#  	conn counts: max: 91, min: 80, mean: 88.78
#  	species: 1, [89]
#
# Generation: 3, Cost time: 1474.76ms
#  	fitness: valid cnt: 89, max: 0.0037, min: -0.0000, mean: 0.0018, std: 0.0013
#
# 	node counts: max: 20, min: 18, mean: 18.98
#  	conn counts: max: 92, min: 80, mean: 88.82
#  	species: 1, [89]
#
# Generation: 4, Cost time: 1458.66ms
#  	fitness: valid cnt: 89, max: 0.0039, min: 0.0000, mean: 0.0027, std: 0.0011
#
# 	node counts: max: 20, min: 17, mean: 18.47
#  	conn counts: max: 91, min: 72, mean: 84.38
#  	species: 1, [89]
#
# Generation: 5, Cost time: 1456.35ms
#  	fitness: valid cnt: 89, max: 0.0039, min: 0.0000, mean: 0.0028, std: 0.0011
#
# 	node counts: max: 19, min: 17, mean: 18.06
#  	conn counts: max: 90, min: 71, mean: 80.28
#  	species: 1, [89]
#
# Generation: 6, Cost time: 1489.88ms
#  	fitness: valid cnt: 89, max: 0.0040, min: 0.0001, mean: 0.0032, std: 0.0011
#
# 	node counts: max: 19, min: 17, mean: 18.15
#  	conn counts: max: 83, min: 71, mean: 80.38
#  	species: 1, [89]
#
# Generation: 7, Cost time: 1576.06ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0001, mean: 0.0038, std: 0.0006
#
# 	node counts: max: 19, min: 16, mean: 17.81
#  	conn counts: max: 82, min: 61, mean: 77.30
#  	species: 1, [89]
#
# Generation: 8, Cost time: 1421.28ms
#  	fitness: valid cnt: 89, max: 0.0041, min: -0.0000, mean: 0.0038, std: 0.0008
#
# 	node counts: max: 19, min: 16, mean: 17.36
#  	conn counts: max: 81, min: 62, mean: 72.08
#  	species: 1, [89]
#
# Generation: 9, Cost time: 1571.30ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0006
#
# 	node counts: max: 18, min: 16, mean: 17.04
#  	conn counts: max: 72, min: 62, mean: 69.99
#  	species: 1, [89]
#
# Generation: 10, Cost time: 1338.96ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0008
#
# 	node counts: max: 19, min: 16, mean: 17.27
#  	conn counts: max: 73, min: 61, mean: 70.24
#  	species: 1, [89]
#
# Generation: 11, Cost time: 1372.20ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0008
#
# 	node counts: max: 20, min: 16, mean: 17.26
#  	conn counts: max: 75, min: 59, mean: 69.49
#  	species: 1, [89]
#
# Generation: 12, Cost time: 1473.94ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0002, mean: 0.0037, std: 0.0009
#
# 	node counts: max: 20, min: 16, mean: 17.67
#  	conn counts: max: 75, min: 61, mean: 70.49
#  	species: 1, [89]
#
# Generation: 13, Cost time: 1490.12ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0009
#
# 	node counts: max: 19, min: 16, mean: 17.26
#  	conn counts: max: 73, min: 61, mean: 70.49
#  	species: 1, [89]
#
# Generation: 14, Cost time: 1327.67ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0007
#
# 	node counts: max: 18, min: 16, mean: 17.07
#  	conn counts: max: 73, min: 61, mean: 69.67
#  	species: 1, [89]
#
# Generation: 15, Cost time: 1267.38ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0009
#
# 	node counts: max: 18, min: 16, mean: 17.13
#  	conn counts: max: 73, min: 59, mean: 70.11
#  	species: 1, [89]
#
# Generation: 16, Cost time: 1276.89ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0010
#
# 	node counts: max: 19, min: 16, mean: 17.11
#  	conn counts: max: 73, min: 61, mean: 70.39
#  	species: 1, [89]
#
# Generation: 17, Cost time: 1372.55ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0037, std: 0.0010
#
# 	node counts: max: 18, min: 16, mean: 16.98
#  	conn counts: max: 73, min: 60, mean: 70.17
#  	species: 1, [89]
#
# Generation: 18, Cost time: 1284.99ms
#  	fitness: valid cnt: 89, max: 0.0041, min: -0.0000, mean: 0.0039, std: 0.0007
#
# 	node counts: max: 18, min: 16, mean: 17.02
#  	conn counts: max: 73, min: 61, mean: 70.45
#  	species: 1, [89]
#
# Generation: 19, Cost time: 1569.66ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0007
#
# 	node counts: max: 18, min: 16, mean: 17.00
#  	conn counts: max: 72, min: 60, mean: 69.98
#  	species: 1, [89]
#
# Generation: 20, Cost time: 1459.47ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0008
#
# 	node counts: max: 19, min: 16, mean: 17.17
#  	conn counts: max: 73, min: 61, mean: 70.76
#  	species: 1, [89]
#
# Generation: 21, Cost time: 1503.67ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0010
#
# 	node counts: max: 18, min: 16, mean: 17.07
#  	conn counts: max: 73, min: 59, mean: 70.13
#  	species: 1, [89]
#
# Generation: 22, Cost time: 1357.51ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0036, std: 0.0010
#
# 	node counts: max: 18, min: 16, mean: 17.04
#  	conn counts: max: 73, min: 59, mean: 71.20
#  	species: 1, [89]
#
# Generation: 23, Cost time: 1359.06ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0007
#
# 	node counts: max: 19, min: 16, mean: 17.29
#  	conn counts: max: 74, min: 62, mean: 71.69
#  	species: 1, [89]
#
# Generation: 24, Cost time: 1365.04ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0008
#
# 	node counts: max: 19, min: 16, mean: 17.60
#  	conn counts: max: 75, min: 63, mean: 71.92
#  	species: 1, [89]
#
# Generation: 25, Cost time: 1374.67ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0009
#
# 	node counts: max: 19, min: 17, mean: 17.99
#  	conn counts: max: 76, min: 64, mean: 73.17
#  	species: 1, [89]
#
# Generation: 26, Cost time: 1345.58ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0008
#
# 	node counts: max: 19, min: 17, mean: 17.99
#  	conn counts: max: 76, min: 62, mean: 73.40
#  	species: 1, [89]
#
# Generation: 27, Cost time: 1326.60ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0008
#
# 	node counts: max: 20, min: 17, mean: 18.15
#  	conn counts: max: 77, min: 63, mean: 73.80
#  	species: 1, [89]
#
# Generation: 28, Cost time: 1392.98ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0039, std: 0.0006
#
# 	node counts: max: 20, min: 17, mean: 18.45
#  	conn counts: max: 77, min: 64, mean: 73.99
#  	species: 1, [89]
#
# Generation: 29, Cost time: 1424.01ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0002, mean: 0.0039, std: 0.0005
#
# 	node counts: max: 21, min: 18, mean: 19.22
#  	conn counts: max: 78, min: 65, mean: 75.70
#  	species: 1, [89]
#
# Generation: 30, Cost time: 1465.89ms
#  	fitness: valid cnt: 89, max: 0.0041, min: 0.0000, mean: 0.0038, std: 0.0010
#
# 	node counts: max: 21, min: 18, mean: 19.33
#  	conn counts: max: 79, min: 68, mean: 76.44
#  	species: 1, [89]
#
# Generation limit reached!
# 98.52797230705619 43613.10850875532

# %%
import numpy as np
best_path = "./model_archive/tensorneat_checkpoints/genomes/best_genome.npz"
best_genome = np.load(best_path)
print(best_genome)
